# %%
sent="Ram is studying at Malla Reddy University in Hyderabad, India"

# %%
import nltk
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('maxent_ne_chunker_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# True

# %%
# !pip install svgling

# %%
import nltk
from nltk import ne_chunk
from nltk import word_tokenize
ne_chunk(nltk.pos_tag(word_tokenize(sent)),binary=False)
# Out:
# Tree('S', [Tree('GPE', [('Ram', 'NNP')]), ('is', 'VBZ'), ('studying', 'VBG'), ('at', 'IN'), Tree('ORGANIZATION', [('Malla', 'NNP'), ('Reddy', 'NNP'), ('University', 'NNP')]), ('in', 'IN'), Tree('GPE', [('Hyderabad', 'NNP')]), (',', ','), Tree('GPE', [('India', 'NNP')])])

# %%
# !pip install spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#      - ------------------------------------- 0.5/12.8 MB 699.0 kB/s eta 0:00:18
#      -- ------------------------------------ 0.8/12.8 MB 838.9 kB/s eta 0:00:15
#      --- ----------------------------------- 1.0/12.8 MB 915.5 kB/s eta 0:00:13
#      --- ----------------------------------- 1.0/12.8 MB 915.5 kB/s eta 0:00:13
#      --- ----------------------------------- 1.3/12.8 MB 860.9 kB/s eta 0:00:14
#      --- ----------------------------------- 1.3/12.8 MB 860.9 kB/s eta 0:00:14
#      --- ----------------------------------- 1.3/12.8 MB 860.9 kB/s eta 0:00:14
#      ---- ---------------------------------- 1.6/12.8 MB 742.6 kB/s eta 0:00:16
#      ---- ---------------------------------- 1.6/12.8 MB 742.6 kB/s eta 0:00:16
# ...

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp(u"Apple is ready to launch new phone worth $10000 in New york time square")
for ent in doc.ents:
  print(ent.text, ent.start_char, ent.end_char,ent.label_)
# Out:
# Apple 0 5 ORG
# 10000 42 47 MONEY
# New york 51 59 GPE

# %%
import spacy
nlp=spacy.load("en_core_web_sm")

# %%
text="""
Elon Musk, the CEO of SpaceX and Tesla, announced that SpaceX's Starship will be launching its first crewes mission to Mars in 2027.
The mission, which will involve astronatus from NASA, will be the frist of its kind, and it will take palce at the Kennedy Space Center in Florids.
Musk emphasized that the project would push the boundaries of space exploration.
"""

# %%
doc=nlp(text)
for ent in doc.ents:
    print(f"Entity:{ent.text},Label:{ent.label_}")
# Out:
# Entity:Elon Musk,Label:PERSON
# Entity:Tesla,Label:ORG
# Entity:SpaceX,Label:PERSON
# Entity:Starship,Label:PRODUCT
# Entity:first,Label:ORDINAL
# Entity:Mars,Label:LOC
# Entity:2027,Label:DATE
# Entity:NASA,Label:ORG
# Entity:the Kennedy Space Center in Florids,Label:FAC
